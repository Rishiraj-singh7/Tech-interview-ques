# %%
import pandas as pd

# %% [markdown]
# Load the dataset a pandas dataframe. Name the variable as "survey"

# %%
survey = pd.read_csv("Survey-DS.csv")

# %%
survey.head(10)
# Out:
#    response_id collection_date urban_rural               education  \
# 0            1       5-24-2017       Rural               12th Pass
# 1            2       5-24-2017       Rural                Graduate
# 2            3       5-24-2017       Rural                Graduate
# 3            4       5-24-2017       Urban                Graduate
# 4            5       5-24-2017       Rural                Graduate
# 5            6       5-24-2017       Urban                Graduate
# 6            7       5-24-2017       Urban                Graduate
# 7            8       5-24-2017       Rural  Professional Education
# 8            9       5-24-2017       Urban               12th Pass
# 9           10       5-24-2017       Urban               12th Pass
#
#                 income Vote_Now     Past_Vote        CM_satisfaction  \
# 0  ₹ 30,000 - ₹ 50,000      BJP           BJP     Fully Dissatisfied
# 1  ₹ 20,000 - ₹ 30,000     RLSP         JD(U)     Somewhat Satisfied
# ...

# %% [markdown]
# 2 How many samples were collected on each day?

# %%
survey['collection_date'].unique()
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
survey['collection_date'].unique()
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
survey['collection_date'].value_counts()
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
survey['collection_date'].value_counts(ascending= True)
# Out:
# 5-31-2017     557
# 5-30-2017     582
# 5-26-2017     598
# 6-1-2017      607
# 5-29-2017     620
# 5-27-2017     665
# 5-28-2017     761
# 5-25-2017     998
# 5-24-2017    1479
# Name: collection_date, dtype: int64

# %% [markdown]
# 3 What proportion of the total respondents were aged less than 45?

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey['age'] # < 45  (< not support in strings (values)
# Out:
# 0       26
# 1       34
# 2       25
# 3       36
# 4       22
#         ..
# 6862    25
# 6863    30
# 6864    20
# 6865    23
# 6866    33
# Name: age, Length: 6867, dtype: object

# %%
survey.age.dtype
# Out:
# dtype('O')

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.value_counts()
# Out:
# 25      598
# 24      449
# 30      440
# 28      396
# 22      392
# 26      389
# 27      360
# 20      328
# 23      317
# 21      311
# 32      263
# 35      263
# 29      239
# 40      177
# 34      173
# 19      171
# 31      159
# 33      143
# 38      135
# 36      127
# 18      125
# 42      104
# 37       90
# 45       82
# 43       72
# 39       69
# 50       60
# 41       54
# 44       54
# 48       35
# 47       34
# 46       32
# 49       27
# 52       24
# 51       23
# 55       20
# 60       15
# 53       12
# 61       12
# 54       11
# 57       10
# 56        9
# 58        9
# 64        8
# 67        7
# 62        5
# 59        5
# 65        5
# 68        4
# 63        4
# 66        4
# 70        3
# 71        2
# 74        1
# 24ko      1
# 69        1
# 99        1
# 72        1
# 75        1
# 76        1
# Name: age, dtype: int64

# %%
survey['age'].replace({'24ko':24})
survey['age'].replace({'24ko':24}, inplace = True)

# %%
survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.value_counts()
# Out:
# 25    598
# 24    449
# 30    440
# 28    396
# 22    392
# 26    389
# 27    360
# 20    328
# 23    317
# 21    311
# 32    263
# 35    263
# 29    239
# 40    177
# 34    173
# 19    171
# 31    159
# 33    143
# 38    135
# 36    127
# 18    125
# 42    104
# 37     90
# 45     82
# 43     72
# 39     69
# 50     60
# 41     54
# 44     54
# 48     35
# 47     34
# 46     32
# 49     27
# 52     24
# 51     23
# 55     20
# 60     15
# 53     12
# 61     12
# 54     11
# 57     10
# 56      9
# 58      9
# 64      8
# 67      7
# 62      5
# 59      5
# 65      5
# 68      4
# 63      4
# 66      4
# 70      3
# 71      2
# 74      1
# 24      1
# 69      1
# 99      1
# 72      1
# 75      1
# 76      1
# Name: age, dtype: int64

# %%
survey['age'] = survey.age.astype(int)

# %%
survey.age.dtype
# Out:
# dtype('int32')

# %%
survey.head(5)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
survey[survey['age'] < 45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
6399/6867 * 100
# Out:
# 93.18479685452162

# %% [markdown]
#  4 create a new column in the dataframe "age_grp" this column should contain in the grp the respondent belongs to the age groups are 18-25, 25-40, 40-55+ the dataframe should look likw this after the column creation:

# %%
survey.head(4)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)       BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD       RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298

# %%
data = survey.copy()

# %%
data.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
data.insert(10, 'age_group', survey.age)

# %%
data.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22
#
#    age_group gender  assembly_no category    weight
# ...

# %%
data1 = data[(data.age_group >= 18) & (data.age_group < 25)]

# %%
data1.head(3)
# Out:
#     response_id collection_date urban_rural  education               income  \
# 4             5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8             9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
# 14           15       5-24-2017       Rural   Graduate   ₹ 1,50,000 & above
#
#    Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age  \
# 4     JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22
# 8       BJP           BJP  Fully Satisfied  Fully Dissatisfied   23
# 14      BJP           BJP  Fully Satisfied  Fully Dissatisfied   24
#
#     age_group gender  assembly_no category    weight
# 4          22   Male          176       BC  0.333505
# 8          23   Male          181      Gen  0.226477
# 14         24   Male          199      Gen  0.226477

# %%
data1.age_group.unique()
# Out:
# array([22, 23, 24, 19, 21, 18, 20])

# %%
data1['age_group'] = '18-25'
# Out:
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_3376\2139180286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age_group'] = '18-25'

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data2 = data[(data.age_group >= 25) & (data.age_group < 40)]

# %%
data2.head(3)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
# 2   JAP(L)       BJP  Fully Dissatisfied  Somewhat Satisfied   25         25
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419
# 2   Male          191      Gen  0.673762

# %%
data2.age_group.unique()
# Out:
# array([26, 34, 25, 36, 38, 29, 30, 39, 37, 32, 27, 28, 35, 31, 33])

# %%
data2['age_group'] = '25-40'
# Out:
# C:\Users\Rishi\AppData\Local\Temp\ipykernel_3376\1359659790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['age_group'] = '25-40'

# %%
data2.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26     25-40
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34     25-40
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419
